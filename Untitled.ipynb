# %%
import pandas as pd

# %%
url = 'https://www.spotrac.com/mlb/free-agents/'
tables = pd.read_html(url)
tables
# Out:
# [          Player (92) Pos.   Age From   To    Yrs         Dollars  \
#  0       Manny Machado   3B  26.0  LAD   SD   10.0    $300,000,000
#  1      Patrick Corbin   SP  30.0  ARI  WSH    6.0    $140,000,000
#  2      Nathan Eovaldi   SP  29.0  BOS  BOS    4.0     $68,000,000
#  3        A.J. Pollock   CF  31.0  ARI  LAD    5.0     $60,000,000
#  4    Andrew McCutchen   RF  32.0  NYY  PHI    3.0     $50,000,000
#  5        Zack Britton   RP  31.0  NYY  NYY    3.0     $39,000,000
#  6           J.A. Happ   SP  36.0  NYY  NYY    2.0     $34,000,000
#  7    Michael Brantley   LF  32.0  CLE  HOU    2.0     $32,000,000
#  8      Jeurys Familia   RP  29.0  OAK  NYM    3.0     $30,000,000
#  9      Charlie Morton   SP  35.0  HOU   TB    2.0     $30,000,000
#  10         Lance Lynn   SP  32.0  NYY  TEX    3.0     $30,000,000
#  11      Adam Ottavino   RP  33.0  COL  NYY    3.0     $27,000,000
#  12      Andrew Miller   RP  34.0  CLE  STL    2.0     $25,000,000
# ...
